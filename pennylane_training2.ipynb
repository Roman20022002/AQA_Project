# %%
from pennylane_functions2 import loss_function, func_and_deriv, u
from pennylane import numpy as np
import pennylane as qml
import matplotlib.pyplot as plt

# %%
#Set seed:
RANDOM_STATE = 42
seed = np.random.seed(RANDOM_STATE)

epochs = 250
num_qubits = 6
x = np.linspace(0,0.9,20)
l = 5
x0 = 0 
u0 = 1
kappa = 0.1

# %%
def training(epochs):
    losses = []
    theta = np.array(2*np.pi*np.random.random(num_qubits*l*3), requires_grad=True)
    for i in range(epochs):
        print("epoch number = ", i)
        loss = loss_function(x,num_qubits,theta, l, i, epochs)
        print("Current loss:", loss)
        losses.append(loss)
        optimizer = qml.AdamOptimizer()
        theta, cost_val = optimizer.step_and_cost(lambda theta: loss_function(x,num_qubits,theta, l, i, epochs), theta)
        print("Finished optimizing.")
        print()

    return theta, losses

# %%
theta_opt, losses = training(epochs)

#Plot the results
plt.plot(losses)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("With regularization 250 epochs")
plt.savefig("losses_with_regularization_floating_boundary.png")
plt.show()

f, df = func_and_deriv(x, num_qubits, theta_opt, l)

x2 = np.linspace(0,0.9,100)
u_plot = u(x2, x0, u0, kappa)

plt.plot(x2, u_plot, label="u(x)")
plt.plot(x, f, label="f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.title("With regularization 250 epochs")
plt.savefig("f_x_with_regularization_floating_boundary.png")
plt.show()
# Out:
# epoch number =  0
# Current loss: 1603.6899021527124
# Finished optimizing.
#
# epoch number =  1
# Current loss: 1432.093614484635
# Finished optimizing.
#
# epoch number =  2
# Current loss: 1271.5187354612428
# Finished optimizing.
#
# epoch number =  3
# Current loss: 1123.5580718478338
# Finished optimizing.
#
# epoch number =  4
# Current loss: 987.6629148793634
# Finished optimizing.
#
# epoch number =  5
# Current loss: 864.1589446134872
# Finished optimizing.
#
# epoch number =  6
# Current loss: 752.8641336523087
# Finished optimizing.
#
# epoch number =  7
# Current loss: 653.1656273696652
# Finished optimizing.
#
# epoch number =  8
# Current loss: 562.8161012804334
# Finished optimizing.
#
# epoch number =  9
# Current loss: 480.80775310878215
# Finished optimizing.
#
# epoch number =  10
# Current loss: 407.5430626679785
# Finished optimizing.
#
# epoch number =  11
# Current loss: 342.6676374529571
# Finished optimizing.
#
# epoch number =  12
# Current loss: 285.765697080688
# Finished optimizing.
#
# epoch number =  13
# Current loss: 236.149346110273
# Finished optimizing.
#
# epoch number =  14
# Current loss: 192.38426128826967
# Finished optimizing.
#
# epoch number =  15
# Current loss: 155.9057547872007
# Finished optimizing.
#
# epoch number =  16
# Current loss: 124.3532705460285
# Finished optimizing.
#
# epoch number =  17
# Current loss: 98.39679461615535
# Finished optimizing.
#
# epoch number =  18
# Current loss: 76.46232517203259
# Finished optimizing.
#
# epoch number =  19
# Current loss: 58.13397153608526
# Finished optimizing.
#
# epoch number =  20
# Current loss: 43.80242615890166
# Finished optimizing.
#
# epoch number =  21
# Current loss: 32.56189645041518
# Finished optimizing.
#
# epoch number =  22
# Current loss: 24.22202781427012
# Finished optimizing.
#
# epoch number =  23
# Current loss: 18.109938943432887
# Finished optimizing.
#
# epoch number =  24
# Current loss: 13.365227335418888
# Finished optimizing.
#
# epoch number =  25
# Current loss: 9.88619443400489
# Finished optimizing.
#
# epoch number =  26
# Current loss: 7.468844952378336
# Finished optimizing.
#
# epoch number =  27
# Current loss: 5.916046527542986
# Finished optimizing.
#
# epoch number =  28
# Current loss: 5.070784525570784
# Finished optimizing.
#
# epoch number =  29
# Current loss: 5.741132633402909
# Finished optimizing.
#
# epoch number =  30
# Current loss: 5.055428773540172
# Finished optimizing.
#
# epoch number =  31
# Current loss: 5.543177380918984
# Finished optimizing.
#
# epoch number =  32
# Current loss: 4.961415647914994
# Finished optimizing.
#
# epoch number =  33
# Current loss: 5.293813327385502
# Finished optimizing.
#
# epoch number =  34
# Current loss: 4.831546933062095
# Finished optimizing.
#
# epoch number =  35
# Current loss: 5.247627624204858
# Finished optimizing.
#
# epoch number =  36
# Current loss: 4.682526151684557
# Finished optimizing.
#
# epoch number =  37
# Current loss: 5.141886234376738
# Finished optimizing.
#
# epoch number =  38
# Current loss: 4.573908972974973
# Finished optimizing.
#
# epoch number =  39
# Current loss: 5.016882736185976
# Finished optimizing.
#
# epoch number =  40
# Current loss: 4.518723659374354
# Finished optimizing.
#
# epoch number =  41
# Current loss: 4.966206371129068
# Finished optimizing.
#
# epoch number =  42
# Current loss: 4.450660658128335
# Finished optimizing.
#
# epoch number =  43
# Current loss: 4.891005790894027
# Finished optimizing.
#
# epoch number =  44
# Current loss: 4.401356904727119
# Finished optimizing.
#
# epoch number =  45
# Current loss: 4.779243318837749
# Finished optimizing.
#
# epoch number =  46
# Current loss: 4.371127548262845
# Finished optimizing.
#
# epoch number =  47
# Current loss: 4.671010141012927
# Finished optimizing.
#
# epoch number =  48
# Current loss: 4.351969306663388
# Finished optimizing.
#
# epoch number =  49
# Current loss: 4.566280670001779
# Finished optimizing.
#
# epoch number =  50
# Current loss: 4.349606720726262
# Finished optimizing.
#
# epoch number =  51
# Current loss: 4.4553570116507295
# Finished optimizing.
#
# epoch number =  52
# Current loss: 4.377301116976962
# Finished optimizing.
#
# epoch number =  53
# Current loss: 4.357027650489325
# Finished optimizing.
#
# epoch number =  54
# Current loss: 4.377704424357536
# Finished optimizing.
#
# epoch number =  55
# Current loss: 4.339114212397193
# Finished optimizing.
#
# epoch number =  56
# Current loss: 4.375841811858425
# Finished optimizing.
#
# epoch number =  57
# Current loss: 4.3336870489681
# Finished optimizing.
#
# epoch number =  58
# Current loss: 4.370022713269287
# Finished optimizing.
#
# epoch number =  59
# Current loss: 4.328236707574603
# Finished optimizing.
#
# epoch number =  60
# Current loss: 4.364168637885636
# Finished optimizing.
#
# epoch number =  61
# Current loss: 4.322763281532252
# Finished optimizing.
#
# epoch number =  62
# Current loss: 4.358279564708897
# Finished optimizing.
#
# epoch number =  63
# Current loss: 4.317266875290226
# Finished optimizing.
#
# epoch number =  64
# Current loss: 4.3523554885766655
# Finished optimizing.
#
# epoch number =  65
# Current loss: 4.31174760456586
# Finished optimizing.
#
# epoch number =  66
# Current loss: 4.346396420291559
# Finished optimizing.
#
# epoch number =  67
# Current loss: 4.30620559642923
# Finished optimizing.
#
# epoch number =  68
# Current loss: 4.340402386744105
# Finished optimizing.
#
# epoch number =  69
# Current loss: 4.300640989364291
# Finished optimizing.
#
# epoch number =  70
# Current loss: 4.334373431026327
# Finished optimizing.
#
# epoch number =  71
# Current loss: 4.295053933317172
# Finished optimizing.
#
# epoch number =  72
# Current loss: 4.32830961253756
# Finished optimizing.
#
# epoch number =  73
# Current loss: 4.289444589732232
# Finished optimizing.
#
# epoch number =  74
# Current loss: 4.322211007079373
# Finished optimizing.
#
# epoch number =  75
# Current loss: 4.283813131579199
# Finished optimizing.
#
# epoch number =  76
# Current loss: 4.316077706940072
# Finished optimizing.
#
# epoch number =  77
# Current loss: 4.278159743370138
# Finished optimizing.
#
# epoch number =  78
# Current loss: 4.309909820969947
# Finished optimizing.
#
# epoch number =  79
# Current loss: 4.272484621167273
# Finished optimizing.
#
# epoch number =  80
# Current loss: 4.303707474644094
# Finished optimizing.
#
# epoch number =  81
# Current loss: 4.266787972582113
# Finished optimizing.
#
# epoch number =  82
# Current loss: 4.29747081011563
# Finished optimizing.
#
# epoch number =  83
# Current loss: 4.261070016763953
# Finished optimizing.
#
# epoch number =  84
# Current loss: 4.291199986256591
# Finished optimizing.
#
# epoch number =  85
# Current loss: 4.25533098438036
# Finished optimizing.
#
# epoch number =  86
# Current loss: 4.284895178687949
# Finished optimizing.
#
# epoch number =  87
# Current loss: 4.2495711175872755
# Finished optimizing.
#
# epoch number =  88
# Current loss: 4.278556579798315
# Finished optimizing.
#
# epoch number =  89
# Current loss: 4.243790669990344
# Finished optimizing.
#
# epoch number =  90
# Current loss: 4.272184398749553
# Finished optimizing.
#
# epoch number =  91
# Current loss: 4.237989906595543
# Finished optimizing.
#
# epoch number =  92
# Current loss: 4.26577886147242
# Finished optimizing.
#
# epoch number =  93
# Current loss: 4.232169103751478
# Finished optimizing.
#
# epoch number =  94
# Current loss: 4.259340210648042
# Finished optimizing.
#
# epoch number =  95
# Current loss: 4.226328549080867
# Finished optimizing.
#
# epoch number =  96
# Current loss: 4.2528687056796235
# Finished optimizing.
#
# epoch number =  97
# Current loss: 4.2204685414034495
# Finished optimizing.
#
# epoch number =  98
# Current loss: 4.246364622649556
# Finished optimizing.
#
# epoch number =  99
# Current loss: 4.21458939064756
# Finished optimizing.
#
# epoch number =  100
# Current loss: 4.239828254265846
# Finished optimizing.
#
# epoch number =  101
# Current loss: 4.208691417753413
# Finished optimizing.
#
# epoch number =  102
# Current loss: 4.2332599097956525
# Finished optimizing.
#
# epoch number =  103
# Current loss: 4.202774954566025
# Finished optimizing.
#
# epoch number =  104
# Current loss: 4.226659914985907
# Finished optimizing.
#
# epoch number =  105
# Current loss: 4.196840343718126
# Finished optimizing.
#
# epoch number =  106
# Current loss: 4.2200286119721975
# Finished optimizing.
#
# epoch number =  107
# Current loss: 4.190887938503845
# Finished optimizing.
#
# epoch number =  108
# Current loss: 4.213366359174783
# Finished optimizing.
#
# epoch number =  109
# Current loss: 4.184918102742049
# Finished optimizing.
#
# epoch number =  110
# Current loss: 4.206673531182047
# Finished optimizing.
#
# epoch number =  111
# Current loss: 4.178931210631009
# Finished optimizing.
#
# epoch number =  112
# Current loss: 4.199950518620943
# Finished optimizing.
#
# epoch number =  113
# Current loss: 4.172927646592094
# Finished optimizing.
#
# epoch number =  114
# Current loss: 4.193197728016348
# Finished optimizing.
#
# epoch number =  115
# Current loss: 4.166907805105095
# Finished optimizing.
#
# epoch number =  116
# Current loss: 4.186415581636842
# Finished optimizing.
#
# epoch number =  117
# Current loss: 4.160872090533857
# Finished optimizing.
#
# epoch number =  118
# Current loss: 4.179604517327728
# Finished optimizing.
#
# epoch number =  119
# Current loss: 4.1548209169419685
# Finished optimizing.
#
# epoch number =  120
# Current loss: 4.172764988332391
# Finished optimizing.
#
# epoch number =  121
# Current loss: 4.1487547078998706
# Finished optimizing.
#
# epoch number =  122
# Current loss: 4.165897463101737
# Finished optimizing.
#
# epoch number =  123
# Current loss: 4.1426738962828225
# Finished optimizing.
#
# epoch number =  124
# Current loss: 4.159002425090433
# Finished optimizing.
#
# epoch number =  125
# Current loss: 4.136578924058949
# Finished optimizing.
#
# epoch number =  126
# Current loss: 4.152080372541399
# Finished optimizing.
#
# epoch number =  127
# Current loss: 4.1304702420701656
# Finished optimizing.
#
# epoch number =  128
# Current loss: 4.145131818259131
# Finished optimizing.
#
# epoch number =  129
# Current loss: 4.124348309802497
# Finished optimizing.
#
# epoch number =  130
# Current loss: 4.1381572893695875
# Finished optimizing.
#
# epoch number =  131
# Current loss: 4.118213595149568
# Finished optimizing.
#
# epoch number =  132
# Current loss: 4.131157327070193
# Finished optimizing.
#
# epoch number =  133
# Current loss: 4.112066574166287
# Finished optimizing.
#
# epoch number =  134
# Current loss: 4.124132486367128
# Finished optimizing.
#
# epoch number =  135
# Current loss: 4.105907730815654
# Finished optimizing.
#
# epoch number =  136
# Current loss: 4.117083335801508
# Finished optimizing.
#
# epoch number =  137
# Current loss: 4.099737556706863
# Finished optimizing.
#
# epoch number =  138
# Current loss: 4.1100104571644485
# Finished optimizing.
#
# epoch number =  139
# Current loss: 4.09355655082586
# Finished optimizing.
#
# epoch number =  140
# Current loss: 4.102914445201671
# Finished optimizing.
#
# epoch number =  141
# Current loss: 4.087365219258583
# Finished optimizing.
#
# epoch number =  142
# Current loss: 4.095795907306346
# Finished optimizing.
#
# epoch number =  143
# Current loss: 4.0811640749062725
# Finished optimizing.
#
# epoch number =  144
# Current loss: 4.088655463203025
# Finished optimizing.
#
# epoch number =  145
# Current loss: 4.074953637195092
# Finished optimizing.
#
# epoch number =  146
# Current loss: 4.081493744619234
# Finished optimizing.
#
# epoch number =  147
# Current loss: 4.068734431777675
# Finished optimizing.
#
# epoch number =  148
# Current loss: 4.074311394949358
# Finished optimizing.
#
# epoch number =  149
# Current loss: 4.062506990228318
# Finished optimizing.
#
# epoch number =  150
# Current loss: 4.0671090689065785
# Finished optimizing.
#
# epoch number =  151
# Current loss: 4.056271849733109
# Finished optimizing.
#
# epoch number =  152
# Current loss: 4.059887432167514
# Finished optimizing.
#
# epoch number =  153
# Current loss: 4.05002955277248
# Finished optimizing.
#
# epoch number =  154
# Current loss: 4.052647161005837
# Finished optimizing.
#
# epoch number =  155
# Current loss: 4.043780646799146
# Finished optimizing.
#
# epoch number =  156
# Current loss: 4.045388941918401
# Finished optimizing.
#
# epoch number =  157
# Current loss: 4.037525683910827
# Finished optimizing.
#
# epoch number =  158
# Current loss: 4.038113471242339
# Finished optimizing.
#
# epoch number =  159
# Current loss: 4.031265220516822
# Finished optimizing.
#
# epoch number =  160
# Current loss: 4.030821454763575
# Finished optimizing.
#
# epoch number =  161
# Current loss: 4.024999817000892
# Finished optimizing.
#
# epoch number =  162
# Current loss: 4.02351360731834
# Finished optimizing.
#
# epoch number =  163
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 theta_opt, losses = training(epochs)
#       3 #Plot the results
#       4 plt.plot(losses)
#
# Cell In [3], line 6, in training(epochs)
#       4 for i in range(epochs):
#       5     print("epoch number = ", i)
# ----> 6     loss = loss_function(x,num_qubits,theta, l, i, epochs)
#       7     print("Current loss:", loss)
#       8     losses.append(loss)
#
# File ~/master/q3/AQA/AQA_Project/pennylane_functions2.py:161, in loss_function(x, num_qubits, theta, l, n_iter, epochs)
#     160 def loss_function(x,num_qubits, theta, l, n_iter, epochs):
# --> 161     f, df = func_and_deriv(x,num_qubits, theta, l)
#     162     loss = diff_loss(f, df, x) + reg_loss(x, num_qubits, theta, l, n_iter, epochs) #+ boundary_loss(f[0])
#     163     return loss
#
# File ~/master/q3/AQA/AQA_Project/pennylane_functions2.py:122, in func_and_deriv(x, num_qubits, theta, l)
#     120 for i in x:
#     121     f.append(f_func(i,num_qubits,theta,l) + (1-f_func(0, num_qubits, theta, l)))
# --> 122     df.append(df_func(i,num_qubits,theta,l))
#     124 return np.array(f), np.array(df)
#
# File ~/master/q3/AQA/AQA_Project/pennylane_functions2.py:108, in df_func(x, num_qubits, theta, l)
#     106 dev = qml.device('default.qubit', wires=list(range(num_qubits)))
#     107 circuit = qml.QNode(build_circuit, dev)
# --> 108 result = circuit(x, num_qubits, i, theta, l)
#     109 # qml.drawer.use_style('black_white')
#     110 # fig, ax = qml.draw_mpl(circuit)(x, num_qubits, i, theta, l)
#     111 # plt.show()
#     112 C_minus += result
#
# File ~/.local/lib/python3.10/site-packages/pennylane/workflow/qnode.py:1092, in QNode.__call__(self, *args, **kwargs)
#    1089     override_shots = kwargs["shots"]
#    1091 # construct the tape
# -> 1092 self.construct(args, kwargs)
#    1094 original_grad_fn = [self.gradient_fn, self.gradient_kwargs, self.device]
#    1095 self._update_gradient_fn(shots=override_shots, tape=self._tape)
#
# File ~/.local/lib/python3.10/site-packages/pennylane/workflow/qnode.py:931, in QNode.construct(self, args, kwargs)
#     928 with qml.queuing.AnnotatedQueue() as q:
#     929     self._qfunc_output = self.func(*args, **kwargs)
# --> 931 self._tape = QuantumScript.from_queue(q, shots)
#     933 params = self.tape.get_parameters(trainable_only=False)
#     934 self.tape.trainable_params = qml.math.get_trainable_indices(params)
#
# File ~/.local/lib/python3.10/site-packages/pennylane/tape/qscript.py:1123, in QuantumScript.from_queue(cls, queue, shots)
#    1120 @classmethod
#    1121 def from_queue(cls, queue, shots: Optional[Union[int, Sequence, Shots]] = None):
#    1122     """Construct a QuantumScript from an AnnotatedQueue."""
# -> 1123     return cls(*process_queue(queue), shots=shots)
#
# File ~/.local/lib/python3.10/site-packages/pennylane/tape/qscript.py:208, in QuantumScript.__init__(self, ops, measurements, shots, trainable_params, _update)
#     205 self._obs_sharing_wires_id = []
#     207 if _update:
# --> 208     self._update()
#
# File ~/.local/lib/python3.10/site-packages/pennylane/tape/qscript.py:403, in QuantumScript._update(self)
#     401 self._graph = None
#     402 self._specs = None
# --> 403 self._update_circuit_info()  # Updates wires, num_wires; O(ops+obs)
#     404 self._update_par_info()  # Updates _par_info; O(ops+obs)
#     406 self._update_observables()
#
# File ~/.local/lib/python3.10/site-packages/pennylane/tape/qscript.py:415, in QuantumScript._update_circuit_info(self)
#     408 def _update_circuit_info(self):
#     409     """Update circuit metadata
#     410
#     411     Sets:
#     412         wires (~.Wires): Wires
#     413         num_wires (int): Number of wires
#     414     """
# --> 415     self.wires = Wires.all_wires(dict.fromkeys(op.wires for op in self))
#     416     self.num_wires = len(self.wires)
#
# File ~/.local/lib/python3.10/site-packages/pennylane/tape/qscript.py:415, in <genexpr>(.0)
#     408 def _update_circuit_info(self):
#     409     """Update circuit metadata
#     410
#     411     Sets:
#     412         wires (~.Wires): Wires
#     413         num_wires (int): Number of wires
#     414     """
# --> 415     self.wires = Wires.all_wires(dict.fromkeys(op.wires for op in self))
#     416     self.num_wires = len(self.wires)
#
# File ~/.local/lib/python3.10/site-packages/pennylane/ops/op_math/controlled.py:513, in Controlled.wires(self)
#     511 @property
#     512 def wires(self):
# --> 513     return self.control_wires + self.target_wires + self.work_wires
#
# File ~/.local/lib/python3.10/site-packages/pennylane/wires.py:178, in Wires.__add__(self, other)
#     162 """Defines the addition to return a Wires object containing all wires of the two terms.
#     163
#     164 Args:
#    (...)
#     175 Wires([4, 0, 1, 2])
#     176 """
#     177 other = Wires(other)
# --> 178 return Wires.all_wires([self, other])
#
# File ~/.local/lib/python3.10/site-packages/pennylane/wires.py:437, in Wires.all_wires(list_of_wires, sort)
#     413 """Return the wires that appear in any of the Wires objects in the list.
#     414
#     415 This is similar to a set combine method, but keeps the order of wires as they appear in the list.
#    (...)
#     432 <Wires = [4, 0, 1, 3, 5]>
#     433 """
#     434 converted_wires = (
#     435     wires if isinstance(wires, Wires) else Wires(wires) for wires in list_of_wires
#     436 )
# --> 437 all_wires_list = itertools.chain(*(w.labels for w in converted_wires))
#     438 combined = list(dict.fromkeys(all_wires_list))
#     440 if sort:
#
# File ~/.local/lib/python3.10/site-packages/pennylane/wires.py:437, in <genexpr>(.0)
#     413 """Return the wires that appear in any of the Wires objects in the list.
#     414
#     415 This is similar to a set combine method, but keeps the order of wires as they appear in the list.
#    (...)
#     432 <Wires = [4, 0, 1, 3, 5]>
#     433 """
#     434 converted_wires = (
#     435     wires if isinstance(wires, Wires) else Wires(wires) for wires in list_of_wires
#     436 )
# --> 437 all_wires_list = itertools.chain(*(w.labels for w in converted_wires))
#     438 combined = list(dict.fromkeys(all_wires_list))
#     440 if sort:
#
# File ~/.local/lib/python3.10/site-packages/pennylane/wires.py:435, in <genexpr>(.0)
#     411 @staticmethod
#     412 def all_wires(list_of_wires, sort=False):
#     413     """Return the wires that appear in any of the Wires objects in the list.
#     414
#     415     This is similar to a set combine method, but keeps the order of wires as they appear in the list.
#    (...)
#     432     <Wires = [4, 0, 1, 3, 5]>
#     433     """
#     434     converted_wires = (
# --> 435         wires if isinstance(wires, Wires) else Wires(wires) for wires in list_of_wires
#     436     )
#     437     all_wires_list = itertools.chain(*(w.labels for w in converted_wires))
#     438     combined = list(dict.fromkeys(all_wires_list))
#
# KeyboardInterrupt:

# %%
x2 = np.linspace(0,0.9,100)
u_plot = u(x2, x0, u0, kappa)
