# %%
from pennylane_functions2 import loss_function, func_and_deriv, u
from pennylane import numpy as np
import pennylane as qml
import matplotlib.pyplot as plt

# %%
#Set seed:
RANDOM_STATE = 42
seed = np.random.seed(RANDOM_STATE)

epochs = 250
num_qubits = 6
x = np.linspace(0,0.9,20)
l = 5
x0 = 0 
u0 = 1
lam = 20
kappa = 0.1

# %%
def training(epochs):
    losses = []
    theta = np.array(2*np.pi*np.random.random(num_qubits*l*3), requires_grad=True)
    for i in range(epochs):
        print("epoch number = ", i)
        loss = loss_function(x,num_qubits,theta, l, i, epochs)
        print("Current loss:", loss)
        losses.append(loss)
        optimizer = qml.AdamOptimizer()
        theta, cost_val = optimizer.step_and_cost(lambda theta: loss_function(x,num_qubits,theta, l, i, epochs), theta)
        print("Finished optimizing.")
        print()

    return theta, losses

# %%
theta_opt, losses = training(epochs)

#Plot the results
plt.plot(losses)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("With regularization 250 epochs")
plt.savefig("losses_with_regularization_floating_boundary.png")
plt.show()

f, df = func_and_deriv(x, num_qubits, theta_opt, l)

x2 = np.linspace(0,0.9,100)
u_plot = u(x2, x0, u0, kappa, lam)

plt.plot(x2, u_plot, label="u(x)")
plt.plot(x, f, label="f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.title("With regularization 250 epochs")
plt.savefig("f_x_with_regularization_floating_boundary.png")
plt.show()

# plt.plot(x, f, label="f")
# plt.xlabel("x")
# plt.ylabel("f(x)")
# plt.legend()
# plt.show()
# Out:
# epoch number =  0
# Current loss: 43.104296082052315
# Finished optimizing.
#
# epoch number =  1
# Current loss: 30.04671524561504
# Finished optimizing.
#
# epoch number =  2
# Current loss: 21.462491455497414
# Finished optimizing.
#
# epoch number =  3
# Current loss: 16.535071581915116
# Finished optimizing.
#
# epoch number =  4
# Current loss: 12.770133652664267
# Finished optimizing.
#
# epoch number =  5
# Current loss: 10.394020371135912
# Finished optimizing.
#
# epoch number =  6
# Current loss: 9.100148688034409
# Finished optimizing.
#
# epoch number =  7
# Current loss: 9.324013865592805
# Finished optimizing.
#
# epoch number =  8
# Current loss: 8.681786319356766
# Finished optimizing.
#
# epoch number =  9
# Current loss: 8.821938369199335
# Finished optimizing.
#
# epoch number =  10
# Current loss: 8.26394817748104
# Finished optimizing.
#
# epoch number =  11
# Current loss: 8.409348112745754
# Finished optimizing.
#
# epoch number =  12
# Current loss: 7.865671916046265
# Finished optimizing.
#
# epoch number =  13
# Current loss: 7.880906179195154
# Finished optimizing.
#
# epoch number =  14
# Current loss: 7.383037862275259
# Finished optimizing.
#
# epoch number =  15
# Current loss: 7.401819634285047
# Finished optimizing.
#
# epoch number =  16
# Current loss: 7.097272104662413
# Finished optimizing.
#
# epoch number =  17
# Current loss: 7.10314395792242
# Finished optimizing.
#
# epoch number =  18
# Current loss: 6.586340370440352
# Finished optimizing.
#
# epoch number =  19
# Current loss: 6.777506873844737
# Finished optimizing.
#
# epoch number =  20
# Current loss: 6.287425887726464
# Finished optimizing.
#
# epoch number =  21
# Current loss: 6.4622387739423495
# Finished optimizing.
#
# epoch number =  22
# Current loss: 6.009433530346748
# Finished optimizing.
#
# epoch number =  23
# Current loss: 6.255447505999811
# Finished optimizing.
#
# epoch number =  24
# Current loss: 5.76565925135907
# Finished optimizing.
#
# epoch number =  25
# Current loss: 6.108993455562542
# Finished optimizing.
#
# epoch number =  26
# Current loss: 5.520506302063601
# Finished optimizing.
#
# epoch number =  27
# Current loss: 5.892187337449307
# Finished optimizing.
#
# epoch number =  28
# Current loss: 5.450965113977259
# Finished optimizing.
#
# epoch number =  29
# Current loss: 5.764143578044377
# Finished optimizing.
#
# epoch number =  30
# Current loss: 5.391928820098732
# Finished optimizing.
#
# epoch number =  31
# Current loss: 5.653594897498192
# Finished optimizing.
#
# epoch number =  32
# Current loss: 5.353590212775457
# Finished optimizing.
#
# epoch number =  33
# Current loss: 5.535120373291662
# Finished optimizing.
#
# epoch number =  34
# Current loss: 5.320228801105168
# Finished optimizing.
#
# epoch number =  35
# Current loss: 5.444991253082825
# Finished optimizing.
#
# epoch number =  36
# Current loss: 5.288927191110963
# Finished optimizing.
#
# epoch number =  37
# Current loss: 5.357549785521868
# Finished optimizing.
#
# epoch number =  38
# Current loss: 5.13977212058201
# Finished optimizing.
#
# epoch number =  39
# Current loss: 5.27130229996108
# Finished optimizing.
#
# epoch number =  40
# Current loss: 5.120375494145052
# Finished optimizing.
#
# epoch number =  41
# Current loss: 5.189560572757473
# Finished optimizing.
#
# epoch number =  42
# Current loss: 5.094843235640061
# Finished optimizing.
#
# epoch number =  43
# Current loss: 5.116021138430171
# Finished optimizing.
#
# epoch number =  44
# Current loss: 5.055211391073572
# Finished optimizing.
#
# epoch number =  45
# Current loss: 5.047974026763008
# Finished optimizing.
#
# epoch number =  46
# Current loss: 4.99978219052771
# Finished optimizing.
#
# epoch number =  47
# Current loss: 4.945530676722225
# Finished optimizing.
#
# epoch number =  48
# Current loss: 4.966282542864724
# Finished optimizing.
#
# epoch number =  49
# Current loss: 4.914279781874991
# Finished optimizing.
#
# epoch number =  50
# Current loss: 4.826937672905587
# Finished optimizing.
#
# epoch number =  51
# Current loss: 4.866001613518547
# Finished optimizing.
#
# epoch number =  52
# Current loss: 4.7933589743741685
# Finished optimizing.
#
# epoch number =  53
# Current loss: 4.840525664523797
# Finished optimizing.
#
# epoch number =  54
# Current loss: 4.7731990993400055
# Finished optimizing.
#
# epoch number =  55
# Current loss: 4.812385666892606
# Finished optimizing.
#
# epoch number =  56
# Current loss: 4.765280395733963
# Finished optimizing.
#
# epoch number =  57
# Current loss: 4.795260586644788
# Finished optimizing.
#
# epoch number =  58
# Current loss: 4.746908111621211
# Finished optimizing.
#
# epoch number =  59
# Current loss: 4.742621798634336
# Finished optimizing.
#
# epoch number =  60
# Current loss: 4.728346977734368
# Finished optimizing.
#
# epoch number =  61
# Current loss: 4.7296551587632285
# Finished optimizing.
#
# epoch number =  62
# Current loss: 4.711785332461209
# Finished optimizing.
#
# epoch number =  63
# Current loss: 4.7093862682031045
# Finished optimizing.
#
# epoch number =  64
# Current loss: 4.703423813663387
# Finished optimizing.
#
# epoch number =  65
# Current loss: 4.7027924732937185
# Finished optimizing.
#
# epoch number =  66
# Current loss: 4.6965206833565905
# Finished optimizing.
#
# epoch number =  67
# Current loss: 4.696198696835775
# Finished optimizing.
#
# epoch number =  68
# Current loss: 4.689617553109929
# Finished optimizing.
#
# epoch number =  69
# Current loss: 4.689604935557136
# Finished optimizing.
#
# epoch number =  70
# Current loss: 4.682714422910157
# Finished optimizing.
#
# epoch number =  71
# Current loss: 4.683011186974618
# Finished optimizing.
#
# epoch number =  72
# Current loss: 4.675811292745464
# Finished optimizing.
#
# epoch number =  73
# Current loss: 4.676417449156618
# Finished optimizing.
#
# epoch number =  74
# Current loss: 4.668908162604876
# Finished optimizing.
#
# epoch number =  75
# Current loss: 4.669823720568681
# Finished optimizing.
#
# epoch number =  76
# Current loss: 4.66200503247814
# Finished optimizing.
#
# epoch number =  77
# Current loss: 4.663229999969261
# Finished optimizing.
#
# epoch number =  78
# Current loss: 4.655101902355619
# Finished optimizing.
#
# epoch number =  79
# Current loss: 4.656636286337409
# Finished optimizing.
#
# epoch number =  80
# Current loss: 4.6481987722280635
# Finished optimizing.
#
# epoch number =  81
# Current loss: 4.65004257882121
# Finished optimizing.
#
# epoch number =  82
# Current loss: 4.64129564208651
# Finished optimizing.
#
# epoch number =  83
# Current loss: 4.643448876700048
# Finished optimizing.
#
# epoch number =  84
# Current loss: 4.634392511922252
# Finished optimizing.
#
# epoch number =  85
# Current loss: 4.63685517935659
# Finished optimizing.
#
# epoch number =  86
# Current loss: 4.627489381726643
# Finished optimizing.
#
# epoch number =  87
# Current loss: 4.630261486255397
# Finished optimizing.
#
# epoch number =  88
# Current loss: 4.620586251491203
# Finished optimizing.
#
# epoch number =  89
# Current loss: 4.62366779692644
# Finished optimizing.
#
# epoch number =  90
# Current loss: 4.613683121207444
# Finished optimizing.
#
# epoch number =  91
# Current loss: 4.617074110951805
# Finished optimizing.
#
# epoch number =  92
# Current loss: 4.606779990866828
# Finished optimizing.
#
# epoch number =  93
# Current loss: 4.610480427955318
# Finished optimizing.
#
# epoch number =  94
# Current loss: 4.599876860460725
# Finished optimizing.
#
# epoch number =  95
# Current loss: 4.603886747593399
# Finished optimizing.
#
# epoch number =  96
# Current loss: 4.592973729980405
# Finished optimizing.
#
# epoch number =  97
# Current loss: 4.597293069547847
# Finished optimizing.
#
# epoch number =  98
# Current loss: 4.586070599416932
# Finished optimizing.
#
# epoch number =  99
# Current loss: 4.590699393518681
# Finished optimizing.
#
# epoch number =  100
# Current loss: 4.579167468761103
# Finished optimizing.
#
# epoch number =  101
# Current loss: 4.5841057192181225
# Finished optimizing.
#
# epoch number =  102
# Current loss: 4.572264338003438
# Finished optimizing.
#
# epoch number =  103
# Current loss: 4.57751204636423
# Finished optimizing.
#
# epoch number =  104
# Current loss: 4.565361207134056
# Finished optimizing.
#
# epoch number =  105
# Current loss: 4.570918374674331
# Finished optimizing.
#
# epoch number =  106
# Current loss: 4.558458076142606
# Finished optimizing.
#
# epoch number =  107
# Current loss: 4.564324703857759
# Finished optimizing.
#
# epoch number =  108
# Current loss: 4.551554945018187
# Finished optimizing.
#
# epoch number =  109
# Current loss: 4.557731033606913
# Finished optimizing.
#
# epoch number =  110
# Current loss: 4.544651813749243
# Finished optimizing.
#
# epoch number =  111
# Current loss: 4.551137363586333
# Finished optimizing.
#
# epoch number =  112
# Current loss: 4.537748682323271
# Finished optimizing.
#
# epoch number =  113
# Current loss: 4.544543693417725
# Finished optimizing.
#
# epoch number =  114
# Current loss: 4.530845550726751
# Finished optimizing.
#
# epoch number =  115
# Current loss: 4.537950022659207
# Finished optimizing.
#
# epoch number =  116
# Current loss: 4.523942418944878
# Finished optimizing.
#
# epoch number =  117
# Current loss: 4.531356350774643
# Finished optimizing.
#
# epoch number =  118
# Current loss: 4.517039286961054
# Finished optimizing.
#
# epoch number =  119
# Current loss: 4.524762677086496
# Finished optimizing.
#
# epoch number =  120
# Current loss: 4.510136154756393
# Finished optimizing.
#
# epoch number =  121
# Current loss: 4.518169000699042
# Finished optimizing.
#
# epoch number =  122
# Current loss: 4.503233022308912
# Finished optimizing.
#
# epoch number =  123
# Current loss: 4.5115753203664015
# Finished optimizing.
#
# epoch number =  124
# Current loss: 4.496329889592115
# Finished optimizing.
#
# epoch number =  125
# Current loss: 4.504981634247258
# Finished optimizing.
#
# epoch number =  126
# Current loss: 4.489426756572859
# Finished optimizing.
#
# epoch number =  127
# Current loss: 4.4983879394062685
# Finished optimizing.
#
# epoch number =  128
# Current loss: 4.482523623207214
# Finished optimizing.
#
# epoch number =  129
# Current loss: 4.491794230662657
# Finished optimizing.
#
# epoch number =  130
# Current loss: 4.475620489432136
# Finished optimizing.
#
# epoch number =  131
# Current loss: 4.485200497395269
# Finished optimizing.
#
# epoch number =  132
# Current loss: 4.468717355145297
# Finished optimizing.
#
# epoch number =  133
# Current loss: 4.47860671154991
# Finished optimizing.
#
# epoch number =  134
# Current loss: 4.461814220140612
# Finished optimizing.
#
# epoch number =  135
# Current loss: 4.472012742211215
# Finished optimizing.
#
# epoch number =  136
# Current loss: 4.454911083731393
# Finished optimizing.
#
# epoch number =  137
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 theta_opt, losses = training(epochs)
#       3 #Plot the results
#       4 plt.plot(losses)
#
# Cell In [3], line 6, in training(epochs)
#       4 for i in range(epochs):
#       5     print("epoch number = ", i)
# ----> 6     loss = loss_function(x,num_qubits,theta, l, i, epochs)
#       7     print("Current loss:", loss)
#       8     losses.append(loss)
#
# File ~/master/q3/AQA/AQA_Project/pennylane_functions.py:161, in loss_function(x, num_qubits, theta, l, n_iter, epochs)
#     160 def loss_function(x,num_qubits, theta, l, n_iter, epochs):
# --> 161     f, df = func_and_deriv(x,num_qubits, theta, l)
#     162     loss = diff_loss(f, df, x) + boundary_loss(f[0]) + reg_loss(x, num_qubits, theta, l, n_iter, epochs)
#     163     return loss
#
# File ~/master/q3/AQA/AQA_Project/pennylane_functions.py:122, in func_and_deriv(x, num_qubits, theta, l)
#     120 for i in x:
#     121     f.append(f_func(i,num_qubits,theta,l))
# --> 122     df.append(df_func(i,num_qubits,theta,l))
#     124 return np.array(f), np.array(df)
#
# File ~/master/q3/AQA/AQA_Project/pennylane_functions.py:100, in df_func(x, num_qubits, theta, l)
#      98 dev = qml.device('default.qubit', wires=list(range(num_qubits)))
#      99 circuit = qml.QNode(build_circuit, dev)
# --> 100 result = circuit(x, num_qubits, i, theta, l)
#     101 # qml.drawer.use_style('black_white')
#     102 # fig, ax = qml.draw_mpl(circuit)(x, num_qubits, i, theta, l)
#     103 # plt.show()
#     104 C_plus += result
#
# File ~/.local/lib/python3.10/site-packages/pennylane/workflow/qnode.py:1098, in QNode.__call__(self, *args, **kwargs)
#    1095 self._update_gradient_fn(shots=override_shots, tape=self._tape)
#    1097 try:
# -> 1098     res = self._execution_component(args, kwargs, override_shots=override_shots)
#    1099 finally:
#    1100     if old_interface == "auto":
#
# File ~/.local/lib/python3.10/site-packages/pennylane/workflow/qnode.py:1052, in QNode._execution_component(self, args, kwargs, override_shots)
#    1049 full_transform_program.prune_dynamic_transform()
#    1051 # pylint: disable=unexpected-keyword-arg
# -> 1052 res = qml.execute(
#    1053     (self._tape,),
#    1054     device=self.device,
#    1055     gradient_fn=self.gradient_fn,
#    1056     interface=self.interface,
#    1057     transform_program=full_transform_program,
#    1058     config=config,
#    1059     gradient_kwargs=self.gradient_kwargs,
#    1060     override_shots=override_shots,
#    1061     **self.execute_kwargs,
#    1062 )
#    1063 res = res[0]
#    1065 # convert result to the interface in case the qfunc has no parameters
#
# File ~/.local/lib/python3.10/site-packages/pennylane/workflow/execution.py:616, in execute(tapes, device, gradient_fn, interface, transform_program, config, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion, device_batch_transform, device_vjp)
#     614 # Exiting early if we do not need to deal with an interface boundary
#     615 if no_interface_boundary_required:
# --> 616     results = inner_execute(tapes)
#     617     return post_processing(results)
#     619 _grad_on_execution = False
#
# File ~/.local/lib/python3.10/site-packages/pennylane/workflow/execution.py:297, in _make_inner_execute.<locals>.inner_execute(tapes, **_)
#     294 transformed_tapes, transform_post_processing = transform_program(tapes)
#     296 if transformed_tapes:
# --> 297     results = device_execution(transformed_tapes)
#     298 else:
#     299     results = ()
#
# File ~/.local/lib/python3.10/site-packages/pennylane/devices/modifiers/simulator_tracking.py:30, in _track_execute.<locals>.execute(self, circuits, execution_config)
#      28 @wraps(untracked_execute)
#      29 def execute(self, circuits, execution_config=DefaultExecutionConfig):
# ---> 30     results = untracked_execute(self, circuits, execution_config)
#      31     if isinstance(circuits, QuantumScript):
#      32         batch = (circuits,)
#
# File ~/.local/lib/python3.10/site-packages/pennylane/devices/modifiers/single_tape_support.py:32, in _make_execute.<locals>.execute(self, circuits, execution_config)
#      30     is_single_circuit = True
#      31     circuits = (circuits,)
# ---> 32 results = batch_execute(self, circuits, execution_config)
#      33 return results[0] if is_single_circuit else results
#
# File ~/.local/lib/python3.10/site-packages/pennylane/devices/default_qubit.py:593, in DefaultQubit.execute(self, circuits, execution_config)
#     590 prng_keys = [self.get_prng_keys()[0] for _ in range(len(circuits))]
#     592 if max_workers is None:
# --> 593     return tuple(
#     594         _simulate_wrapper(
#     595             c,
#     596             {
#     597                 "rng": self._rng,
#     598                 "debugger": self._debugger,
#     599                 "interface": interface,
#     600                 "state_cache": self._state_cache,
#     601                 "prng_key": _key,
#     602             },
#     603         )
#     604         for c, _key in zip(circuits, prng_keys)
#     605     )
#     607 vanilla_circuits = [convert_to_numpy_parameters(c) for c in circuits]
#     608 seeds = self._rng.integers(2**31 - 1, size=len(vanilla_circuits))
#
# File ~/.local/lib/python3.10/site-packages/pennylane/devices/default_qubit.py:594, in <genexpr>(.0)
#     590 prng_keys = [self.get_prng_keys()[0] for _ in range(len(circuits))]
#     592 if max_workers is None:
#     593     return tuple(
# --> 594         _simulate_wrapper(
#     595             c,
#     596             {
#     597                 "rng": self._rng,
#     598                 "debugger": self._debugger,
#     599                 "interface": interface,
#     600                 "state_cache": self._state_cache,
#     601                 "prng_key": _key,
#     602             },
#     603         )
#     604         for c, _key in zip(circuits, prng_keys)
#     605     )
#     607 vanilla_circuits = [convert_to_numpy_parameters(c) for c in circuits]
#     608 seeds = self._rng.integers(2**31 - 1, size=len(vanilla_circuits))
#
# File ~/.local/lib/python3.10/site-packages/pennylane/devices/default_qubit.py:841, in _simulate_wrapper(circuit, kwargs)
#     840 def _simulate_wrapper(circuit, kwargs):
# --> 841     return simulate(circuit, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pennylane/devices/qubit/simulate.py:287, in simulate(circuit, debugger, state_cache, **execution_kwargs)
#     282     return simulate_one_shot_native_mcm(
#     283         circuit, debugger=debugger, rng=rng, prng_key=prng_key, interface=interface
#     284     )
#     286 ops_key, meas_key = jax_random_split(prng_key)
# --> 287 state, is_state_batched = get_final_state(
#     288     circuit, debugger=debugger, rng=rng, prng_key=ops_key, interface=interface
#     289 )
#     290 if state_cache is not None:
#     291     state_cache[circuit.hash] = state
#
# File ~/.local/lib/python3.10/site-packages/pennylane/devices/qubit/simulate.py:167, in get_final_state(circuit, debugger, **execution_kwargs)
#     162         state, circuit._shots = _postselection_postprocess(
#     163             state, is_state_batched, circuit.shots, rng=rng, prng_key=key
#     164         )
#     166     # new state is batched if i) the old state is batched, or ii) the new op adds a batch dim
# --> 167     is_state_batched = is_state_batched or (op.batch_size is not None)
#     169 for _ in range(len(circuit.wires) - len(circuit.op_wires)):
#     170     # if any measured wires are not operated on, we pad the state with zeros.
#     171     # We know they belong at the end because the circuit is in standard wire-order
#     172     state = qml.math.stack([state, qml.math.zeros_like(state)], axis=-1)
#
# File ~/.local/lib/python3.10/site-packages/pennylane/operation.py:1223, in Operator.batch_size(self)
#    1212 r"""Batch size of the operator if it is used with broadcasted parameters.
#    1213
#    1214 The ``batch_size`` is determined based on ``ndim_params`` and the provided parameters
#    (...)
#    1220     int or None: Size of the parameter broadcasting dimension if present, else ``None``.
#    1221 """
#    1222 if self._batch_size is _UNSET_BATCH_SIZE:
# -> 1223     self._check_batching()
#    1224 return self._batch_size
#
# File ~/.local/lib/python3.10/site-packages/pennylane/operation.py:1131, in Operator._check_batching(self)
#    1128 params = self.data
#    1130 try:
# -> 1131     ndims = tuple(qml.math.ndim(p) for p in params)
#    1132 except ValueError as e:
#    1133     # TODO:[dwierichs] When using tf.function with an input_signature that contains
#    1134     # an unknown-shaped input, ndim() will not be able to determine the number of
#    (...)
#    1139     # investigated. For now, the batch_size is left to be `None` when instantiating
#    1140     # an operation with abstract parameters that make `qml.math.ndim` fail.
#    1141     if any(qml.math.is_abstract(p) for p in params):
#
# File ~/.local/lib/python3.10/site-packages/pennylane/operation.py:1131, in <genexpr>(.0)
#    1128 params = self.data
#    1130 try:
# -> 1131     ndims = tuple(qml.math.ndim(p) for p in params)
#    1132 except ValueError as e:
#    1133     # TODO:[dwierichs] When using tf.function with an input_signature that contains
#    1134     # an unknown-shaped input, ndim() will not be able to determine the number of
#    (...)
#    1139     # investigated. For now, the batch_size is left to be `None` when instantiating
#    1140     # an operation with abstract parameters that make `qml.math.ndim` fail.
#    1141     if any(qml.math.is_abstract(p) for p in params):
#
# File ~/.local/lib/python3.10/site-packages/autoray/autoray.py:79, in do(fn, like, *args, **kwargs)
#      30 def do(fn, *args, like=None, **kwargs):
#      31     """Do function named ``fn`` on ``(*args, **kwargs)``, peforming single
#      32     dispatch to retrieve ``fn`` based on whichever library defines the class of
#      33     the ``args[0]``, or the ``like`` keyword argument if specified.
#    (...)
#      77         <tf.Tensor: id=91, shape=(3, 3), dtype=float32>
#      78     """
# ---> 79     backend = _choose_backend(fn, args, kwargs, like=like)
#      80     func = get_lib_fn(backend, fn)
#      81     return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/autoray/autoray.py:402, in _choose_backend(fn, args, kwargs, like)
#     395 """Private function to choose a backend based on function name and
#     396 signature, which passes args and kwargs by reference for performance and
#     397 also to allow injection of dtype and device arguments for array creation
#     398 routines.
#     399 """
#     400 if like is None:
#     401     # infer from function call (or global backend)
# --> 402     return _infer_auto(fn, args, kwargs)
#     403 elif isinstance(like, str):
#     404     # explicit backend
#     405     return like
#
# File ~/.local/lib/python3.10/site-packages/autoray/autoray.py:93, in _default_infer_from_sig(fn, *args, **kwargs)
#      87 def _default_infer_from_sig(fn, *args, **kwargs):
#      88     """This is the default backend dispatcher, used if no global backend has
#      89     been set. Hot swapping this function out as below avoids having to check
#      90     manually for a global backend or worse, a thread aware global backend, on
#      91     every call to ``do``.
#      92     """
# ---> 93     return _DISPATCHERS[fn](*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/autoray/autoray.py:1390, in default_dispatcher(args, kwargs)
#    1388 def default_dispatcher(args, kwargs):
#    1389     """Try to infer backend from first argument passed to function."""
# -> 1390     return infer_backend(args[0])
#
# File ~/.local/lib/python3.10/site-packages/autoray/autoray.py:296, in infer_backend(array)
#     291     backend = _BACKEND_ALIASES.get(lib, lib)
#     293     return backend
# --> 296 def infer_backend(array):
#     297     """Get the name of the library that defined the class of ``array`` - unless
#     298     ``array`` is directly a subclass of ``numpy.ndarray``, in which case assume
#     299     ``numpy`` is the desired backend.
#     300     """
#     301     return _infer_class_backend_cached(array.__class__)
#
# KeyboardInterrupt:
