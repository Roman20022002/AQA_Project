# %%
from pennylane_functions2 import loss_function, func_and_deriv, u
from pennylane import numpy as np
import pennylane as qml
import matplotlib.pyplot as plt

# %%
#Set seed:
RANDOM_STATE = 42
seed = np.random.seed(RANDOM_STATE)

epochs = 250
num_qubits = 6
x = np.linspace(0,0.9,20)
l = 5
x0 = 0 
u0 = 1
kappa = 0.1

# %%
def training(epochs):
    losses = []
    theta = np.array(2*np.pi*np.random.random(num_qubits*l*3), requires_grad=True)
    for i in range(epochs):
        print("epoch number = ", i)
        loss = loss_function(x,num_qubits,theta, l, i, epochs)
        print("Current loss:", loss)
        losses.append(loss)
        optimizer = qml.AdamOptimizer()
        theta, cost_val = optimizer.step_and_cost(lambda theta: loss_function(x,num_qubits,theta, l, i, epochs), theta)
        print("Finished optimizing.")
        print()

    return theta, losses

# %%
theta_opt, losses = training(epochs)

#Plot the results
plt.plot(losses)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("With regularization 250 epochs")
plt.savefig("losses_with_regularization_floating_boundary.png")
plt.show()

f, df = func_and_deriv(x, num_qubits, theta_opt, l)

x2 = np.linspace(0,0.9,100)
u_plot = u(x2, x0, u0, kappa)

plt.plot(x2, u_plot, label="u(x)")
plt.plot(x, f, label="f(x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.title("With regularization 250 epochs")
plt.savefig("f_x_with_regularization_floating_boundary.png")
plt.show()
# Out:
# epoch number =  0
# Current loss: 1603.2677519808706
# Finished optimizing.
#
# epoch number =  1
# Current loss: 1431.7087773142505
# Finished optimizing.
#
# epoch number =  2
# Current loss: 1271.1700303045588
# Finished optimizing.
#
# epoch number =  3
# Current loss: 1123.2457844193293
# Finished optimizing.
#
# epoch number =  4
# Current loss: 987.3904799479474
# Finished optimizing.
#
# epoch number =  5
# Current loss: 863.9238224158681
# Finished optimizing.
#
# epoch number =  6
# Current loss: 752.6675831815653
# Finished optimizing.
#
# epoch number =  7
# Current loss: 653.0001681434038
# Finished optimizing.
#
# epoch number =  8
# Current loss: 562.5840503594083
# Finished optimizing.
#
# epoch number =  9
# Current loss: 480.4860080683804
# Finished optimizing.
#
# epoch number =  10
# Current loss: 407.17969675318926
# Finished optimizing.
#
# epoch number =  11
# Current loss: 342.1383158534366
# Finished optimizing.
#
# epoch number =  12
# Current loss: 285.2585335067947
# Finished optimizing.
#
# epoch number =  13
# Current loss: 235.77827484501353
# Finished optimizing.
#
# epoch number =  14
# Current loss: 192.10526361545232
# Finished optimizing.
#
# epoch number =  15
# Current loss: 155.65178062082114
# Finished optimizing.
#
# epoch number =  16
# Current loss: 124.033570693553
# Finished optimizing.
#
# epoch number =  17
# Current loss: 98.15190011011644
# Finished optimizing.
#
# epoch number =  18
# Current loss: 76.2241855958713
# Finished optimizing.
#
# epoch number =  19
# Current loss: 57.87405860601926
# Finished optimizing.
#
# epoch number =  20
# Current loss: 43.62310225108536
# Finished optimizing.
#
# epoch number =  21
# Current loss: 32.33537918473491
# Finished optimizing.
#
# epoch number =  22
# Current loss: 23.979892103513798
# Finished optimizing.
#
# epoch number =  23
# Current loss: 17.918673436709962
# Finished optimizing.
#
# epoch number =  24
# Current loss: 13.187700307256046
# Finished optimizing.
#
# epoch number =  25
# Current loss: 9.724584314319191
# Finished optimizing.
#
# epoch number =  26
# Current loss: 7.317699235215685
# Finished optimizing.
#
# epoch number =  27
# Current loss: 5.711957397359741
# Finished optimizing.
#
# epoch number =  28
# Current loss: 4.820113311798669
# Finished optimizing.
#
# epoch number =  29
# Current loss: 5.617636684227579
# Finished optimizing.
#
# epoch number =  30
# Current loss: 4.73771462427052
# Finished optimizing.
#
# epoch number =  31
# Current loss: 5.455766629978448
# Finished optimizing.
#
# epoch number =  32
# Current loss: 4.5819771447339095
# Finished optimizing.
#
# epoch number =  33
# Current loss: 5.224584609852759
# Finished optimizing.
#
# epoch number =  34
# Current loss: 4.471117764650062
# Finished optimizing.
#
# epoch number =  35
# Current loss: 5.117642970816937
# Finished optimizing.
#
# epoch number =  36
# Current loss: 4.389067649461679
# Finished optimizing.
#
# epoch number =  37
# Current loss: 4.968306197872103
# Finished optimizing.
#
# epoch number =  38
# Current loss: 4.326053321269406
# Finished optimizing.
#
# epoch number =  39
# Current loss: 4.777026413697548
# Finished optimizing.
#
# epoch number =  40
# Current loss: 4.319319840343177
# Finished optimizing.
#
# epoch number =  41
# Current loss: 4.590103897917689
# Finished optimizing.
#
# epoch number =  42
# Current loss: 4.315677030079817
# Finished optimizing.
#
# epoch number =  43
# Current loss: 4.47502921578088
# Finished optimizing.
#
# epoch number =  44
# Current loss: 4.338464834878129
# Finished optimizing.
#
# epoch number =  45
# Current loss: 4.359370192564456
# Finished optimizing.
#
# epoch number =  46
# Current loss: 4.338193089253385
# Finished optimizing.
#
# epoch number =  47
# Current loss: 4.298509773538334
# Finished optimizing.
#
# epoch number =  48
# Current loss: 4.369903498143457
# Finished optimizing.
#
# epoch number =  49
# Current loss: 4.26876050758952
# Finished optimizing.
#
# epoch number =  50
# Current loss: 4.349810087430641
# Finished optimizing.
#
# epoch number =  51
# Current loss: 4.220958341569559
# Finished optimizing.
#
# epoch number =  52
# Current loss: 4.354536523164122
# Finished optimizing.
#
# epoch number =  53
# Current loss: 4.1900766562483955
# Finished optimizing.
#
# epoch number =  54
# Current loss: 4.357656167794718
# Finished optimizing.
#
# epoch number =  55
# Current loss: 4.15246416838873
# Finished optimizing.
#
# epoch number =  56
# Current loss: 4.36917129200966
# Finished optimizing.
#
# epoch number =  57
# Current loss: 4.1253102547844716
# Finished optimizing.
#
# epoch number =  58
# Current loss: 4.368102828514957
# Finished optimizing.
#
# epoch number =  59
# Current loss: 4.120688763169204
# Finished optimizing.
#
# epoch number =  60
# Current loss: 4.363332717595251
# Finished optimizing.
#
# epoch number =  61
# Current loss: 4.116067271741458
# Finished optimizing.
#
# epoch number =  62
# Current loss: 4.358562618722387
# Finished optimizing.
#
# epoch number =  63
# Current loss: 4.111445780469685
# Finished optimizing.
#
# epoch number =  64
# Current loss: 4.353792530125904
# Finished optimizing.
#
# epoch number =  65
# Current loss: 4.106824289323477
# Finished optimizing.
#
# epoch number =  66
# Current loss: 4.349022450409223
# Finished optimizing.
#
# epoch number =  67
# Current loss: 4.102202798272862
# Finished optimizing.
#
# epoch number =  68
# Current loss: 4.344252378451118
# Finished optimizing.
#
# epoch number =  69
# Current loss: 4.0975813072879586
# Finished optimizing.
#
# epoch number =  70
# Current loss: 4.3394823133373555
# Finished optimizing.
#
# epoch number =  71
# Current loss: 4.092959816338943
# Finished optimizing.
#
# epoch number =  72
# Current loss: 4.334712254311898
# Finished optimizing.
#
# epoch number =  73
# Current loss: 4.088338325395284
# Finished optimizing.
#
# epoch number =  74
# Current loss: 4.32994220074265
# Finished optimizing.
#
# epoch number =  75
# Current loss: 4.08371683442618
# Finished optimizing.
#
# epoch number =  76
# Current loss: 4.325172152094758
# Finished optimizing.
#
# epoch number =  77
# Current loss: 4.07909534339975
# Finished optimizing.
#
# epoch number =  78
# Current loss: 4.320402107911918
# Finished optimizing.
#
# epoch number =  79
# Current loss: 4.074473852282805
# Finished optimizing.
#
# epoch number =  80
# Current loss: 4.315632067801469
# Finished optimizing.
#
# epoch number =  81
# Current loss: 4.0698523610409785
# Finished optimizing.
#
# epoch number =  82
# Current loss: 4.3108620314222055
# Finished optimizing.
#
# epoch number =  83
# Current loss: 4.065230869637853
# Finished optimizing.
#
# epoch number =  84
# Current loss: 4.306091998476877
# Finished optimizing.
#
# epoch number =  85
# Current loss: 4.060609378034897
# Finished optimizing.
#
# epoch number =  86
# Current loss: 4.301321968703196
# Finished optimizing.
#
# epoch number =  87
# Current loss: 4.055987886190884
# Finished optimizing.
#
# epoch number =  88
# Current loss: 4.296551941869892
# Finished optimizing.
#
# epoch number =  89
# Current loss: 4.051366394061868
# Finished optimizing.
#
# epoch number =  90
# Current loss: 4.291781917770862
# Finished optimizing.
#
# epoch number =  91
# Current loss: 4.046744901599947
# Finished optimizing.
#
# epoch number =  92
# Current loss: 4.2870118962217
# Finished optimizing.
#
# epoch number =  93
# Current loss: 4.042123408753038
# Finished optimizing.
#
# epoch number =  94
# Current loss: 4.282241877057413
# Finished optimizing.
#
# epoch number =  95
# Current loss: 4.037501915464214
# Finished optimizing.
#
# epoch number =  96
# Current loss: 4.277471860128287
# Finished optimizing.
#
# epoch number =  97
# Current loss: 4.032880421670391
# Finished optimizing.
#
# epoch number =  98
# Current loss: 4.272701845299222
# Finished optimizing.
#
# epoch number =  99
# Current loss: 4.02825892730139
# Finished optimizing.
#
# epoch number =  100
# Current loss: 4.267931832447112
# Finished optimizing.
#
# epoch number =  101
# Current loss: 4.023637432278783
# Finished optimizing.
#
# epoch number =  102
# Current loss: 4.263161821459422
# Finished optimizing.
#
# epoch number =  103
# Current loss: 4.019015936513963
# Finished optimizing.
#
# epoch number =  104
# Current loss: 4.258391812233052
# Finished optimizing.
#
# epoch number =  105
# Current loss: 4.014394439905592
# Finished optimizing.
#
# epoch number =  106
# Current loss: 4.25362180467292
# Finished optimizing.
#
# epoch number =  107
# Current loss: 4.009772942338117
# Finished optimizing.
#
# epoch number =  108
# Current loss: 4.2488517986912955
# Finished optimizing.
#
# epoch number =  109
# Current loss: 4.0051514436769855
# Finished optimizing.
#
# epoch number =  110
# Current loss: 4.244081794207137
# Finished optimizing.
#
# epoch number =  111
# Current loss: 4.000529943765101
# Finished optimizing.
#
# epoch number =  112
# Current loss: 4.239311791144176
# Finished optimizing.
#
# epoch number =  113
# Current loss: 3.9959084424162916
# Finished optimizing.
#
# epoch number =  114
# Current loss: 4.234541789431778
# Finished optimizing.
#
# epoch number =  115
# Current loss: 3.9912869394077255
# Finished optimizing.
#
# epoch number =  116
# Current loss: 4.229771789003251
# Finished optimizing.
#
# epoch number =  117
# Current loss: 3.9866654344691925
# Finished optimizing.
#
# epoch number =  118
# Current loss: 4.225001789795896
# Finished optimizing.
#
# epoch number =  119
# Current loss: 3.9820439272677848
# Finished optimizing.
#
# epoch number =  120
# Current loss: 4.2202317917496535
# Finished optimizing.
#
# epoch number =  121
# Current loss: 3.977422417386322
# Finished optimizing.
#
# epoch number =  122
# Current loss: 4.215461794807621
# Finished optimizing.
#
# epoch number =  123
# Current loss: 3.9728009042919075
# Finished optimizing.
#
# epoch number =  124
# Current loss: 4.210691798914155
# Finished optimizing.
#
# epoch number =  125
# Current loss: 3.968179387287242
# Finished optimizing.
#
# epoch number =  126
# Current loss: 4.2059218040155395
# Finished optimizing.
#
# epoch number =  127
# Current loss: 3.9635578654350603
# Finished optimizing.
#
# epoch number =  128
# Current loss: 4.201151810058224
# Finished optimizing.
#
# epoch number =  129
# Current loss: 3.958936337431788
# Finished optimizing.
#
# epoch number =  130
# Current loss: 4.196381816987642
# Finished optimizing.
#
# epoch number =  131
# Current loss: 3.9543148013863276
# Finished optimizing.
#
# epoch number =  132
# Current loss: 4.191611824747375
# Finished optimizing.
#
# epoch number =  133
# Current loss: 3.949693254402206
# Finished optimizing.
#
# epoch number =  134
# Current loss: 4.186841833275792
# Finished optimizing.
#
# epoch number =  135
# Current loss: 3.9450716917069633
# Finished optimizing.
#
# epoch number =  136
# Current loss: 4.182071842501146
# Finished optimizing.
#
# epoch number =  137
# Current loss: 3.9404501045780966
# Finished optimizing.
#
# epoch number =  138
# Current loss: 4.177301852332581
# Finished optimizing.
#
# epoch number =  139
# Current loss: 3.9358284743089373
# Finished optimizing.
#
# epoch number =  140
# Current loss: 4.172531862634485
# Finished optimizing.
#
# epoch number =  141
# Current loss: 3.9312067475191323
# Finished optimizing.
#
# epoch number =  142
# Current loss: 4.167761873141423
# Finished optimizing.
#
# epoch number =  143
# Current loss: 3.926584611679608
# Finished optimizing.
#
# epoch number =  144
# Current loss: 4.1629918828244135
# Finished optimizing.
#
# epoch number =  145
# Current loss: 3.8940173349905765
# Finished optimizing.
#
# epoch number =  146
# Current loss: 4.16902907490389
# Finished optimizing.
#
# epoch number =  147
# Current loss: 3.881816760411517
# Finished optimizing.
#
# epoch number =  148
# Current loss: 4.169261877130601
# Finished optimizing.
#
# epoch number =  149
# Current loss: 3.8771788857844456
# Finished optimizing.
#
# epoch number =  150
# Current loss: 4.1644710059534225
# Finished optimizing.
#
# epoch number =  151
# Current loss: 3.8725410137978464
# Finished optimizing.
#
# epoch number =  152
# Current loss: 4.159680138229633
# Finished optimizing.
#
# epoch number =  153
# Current loss: 3.867903144128145
# Finished optimizing.
#
# epoch number =  154
# Current loss: 4.1548892736618
# Finished optimizing.
#
# epoch number =  155
# Current loss: 3.863265276506361
# Finished optimizing.
#
# epoch number =  156
# Current loss: 4.15009841198925
# Finished optimizing.
#
# epoch number =  157
# Current loss: 3.8586274107057923
# Finished optimizing.
#
# epoch number =  158
# Current loss: 4.145307552982905
# Finished optimizing.
#
# epoch number =  159
# Current loss: 3.853989546533905
# Finished optimizing.
#
# epoch number =  160
# Current loss: 4.14051669644016
# Finished optimizing.
#
# epoch number =  161
# Current loss: 3.849351683825327
# Finished optimizing.
#
# epoch number =  162
# Current loss: 4.1357258421807845
# Finished optimizing.
#
# epoch number =  163
# Current loss: 3.844713822437055
# Finished optimizing.
#
# epoch number =  164
# Current loss: 4.130934990043863
# Finished optimizing.
#
# epoch number =  165
# Current loss: 3.840075962244245
# Finished optimizing.
#
# epoch number =  166
# Current loss: 4.126144139885009
# Finished optimizing.
#
# epoch number =  167
# Current loss: 3.8354381031371156
# Finished optimizing.
#
# epoch number =  168
# Current loss: 4.121353291574404
# Finished optimizing.
#
# epoch number =  169
# Current loss: 3.83080024501901
# Finished optimizing.
#
# epoch number =  170
# Current loss: 4.116562444994221
# Finished optimizing.
#
# epoch number =  171
# Current loss: 3.826162387803336
# Finished optimizing.
#
# epoch number =  172
# Current loss: 4.1117716000380105
# Finished optimizing.
#
# epoch number =  173
# Current loss: 3.821524531413076
# Finished optimizing.
#
# epoch number =  174
# Current loss: 4.106980756608627
# Finished optimizing.
#
# epoch number =  175
# Current loss: 3.816886675778386
# Finished optimizing.
#
# epoch number =  176
# Current loss: 4.102189914617499
# Finished optimizing.
#
# epoch number =  177
# Current loss: 3.8122488208365213
# Finished optimizing.
#
# epoch number =  178
# Current loss: 4.097399073983475
# Finished optimizing.
#
# epoch number =  179
# Current loss: 3.807610966530208
# Finished optimizing.
#
# epoch number =  180
# Current loss: 4.092608234632287
# Finished optimizing.
#
# epoch number =  181
# Current loss: 3.8029731128071065
# Finished optimizing.
#
# epoch number =  182
# Current loss: 4.0878173964952635
# Finished optimizing.
#
# epoch number =  183
# Current loss: 3.7983352596191113
# Finished optimizing.
#
# epoch number =  184
# Current loss: 4.08302655950921
# Finished optimizing.
#
# epoch number =  185
# Current loss: 3.793697406921906
# Finished optimizing.
#
# epoch number =  186
# Current loss: 4.0782357236155775
# Finished optimizing.
#
# epoch number =  187
# Current loss: 3.789059554674319
# Finished optimizing.
#
# epoch number =  188
# Current loss: 4.073444888759947
# Finished optimizing.
#
# epoch number =  189
# Current loss: 3.7844217028379314
# Finished optimizing.
#
# epoch number =  190
# Current loss: 4.068654054892298
# Finished optimizing.
#
# epoch number =  191
# Current loss: 3.7797838513770836
# Finished optimizing.
#
# epoch number =  192
# Current loss: 4.063863221965488
# Finished optimizing.
#
# epoch number =  193
# Current loss: 3.7751460002580903
# Finished optimizing.
#
# epoch number =  194
# Current loss: 4.059072389935628
# Finished optimizing.
#
# epoch number =  195
# Current loss: 3.770508149449129
# Finished optimizing.
#
# epoch number =  196
# Current loss: 4.0542815587621845
# Finished optimizing.
#
# epoch number =  197
# Current loss: 3.7658702989199972
# Finished optimizing.
#
# epoch number =  198
# Current loss: 4.049490728406429
# Finished optimizing.
#
# epoch number =  199
# Current loss: 3.761232448642125
# Finished optimizing.
#
# epoch number =  200
# Current loss: 4.04469989883292
# Finished optimizing.
#
# epoch number =  201
# Current loss: 3.756594598587917
# Finished optimizing.
#
# epoch number =  202
# Current loss: 4.039909070007698
# Finished optimizing.
#
# epoch number =  203
# Current loss: 3.7519567487310894
# Finished optimizing.
#
# epoch number =  204
# Current loss: 4.035118241899025
# Finished optimizing.
#
# epoch number =  205
# Current loss: 3.747318899046113
# Finished optimizing.
#
# epoch number =  206
# Current loss: 4.030327414476977
# Finished optimizing.
#
# epoch number =  207
# Current loss: 3.742681049508231
# Finished optimizing.
#
# epoch number =  208
# Current loss: 4.025536587713356
# Finished optimizing.
#
# epoch number =  209
# Current loss: 3.738043200093495
# Finished optimizing.
#
# epoch number =  210
# Current loss: 4.02074576158148
# Finished optimizing.
#
# epoch number =  211
# Current loss: 3.733405350778025
# Finished optimizing.
#
# epoch number =  212
# Current loss: 4.015954936056013
# Finished optimizing.
#
# epoch number =  213
# Current loss: 3.728767501538832
# Finished optimizing.
#
# epoch number =  214
# Current loss: 4.0111641111130245
# Finished optimizing.
#
# epoch number =  215
# Current loss: 3.724129652352948
# Finished optimizing.
#
# epoch number =  216
# Current loss: 4.0063732867296595
# Finished optimizing.
#
# epoch number =  217
# Current loss: 3.71949180319733
# Finished optimizing.
#
# epoch number =  218
# Current loss: 4.001582462884424
# Finished optimizing.
#
# epoch number =  219
# Current loss: 3.714853954049367
# Finished optimizing.
#
# epoch number =  220
# Current loss: 3.996791639556773
# Finished optimizing.
#
# epoch number =  221
# Current loss: 3.710216104886215
# Finished optimizing.
#
# epoch number =  222
# Current loss: 3.9920008167267613
# Finished optimizing.
#
# epoch number =  223
# Current loss: 3.7055782556846357
# Finished optimizing.
#
# epoch number =  224
# Current loss: 3.987209994375965
# Finished optimizing.
#
# epoch number =  225
# Current loss: 3.7009404064214033
# Finished optimizing.
#
# epoch number =  226
# Current loss: 3.982419172486075
# Finished optimizing.
#
# epoch number =  227
# Current loss: 3.6963025570725434
# Finished optimizing.
#
# epoch number =  228
# Current loss: 3.9776283510404955
# Finished optimizing.
#
# epoch number =  229
# Current loss: 3.6916647076138367
# Finished optimizing.
#
# epoch number =  230
# Current loss: 3.9728375300222125
# Finished optimizing.
#
# epoch number =  231
# Current loss: 3.6870268580200767
# Finished optimizing.
#
# epoch number =  232
# Current loss: 3.9680467094157796
# Finished optimizing.
#
# epoch number =  233
# Current loss: 3.6823890082652984
# Finished optimizing.
#
# epoch number =  234
# Current loss: 3.9632558892057586
# Finished optimizing.
#
# epoch number =  235
# Current loss: 3.67775115832263
# Finished optimizing.
#
# epoch number =  236
# Current loss: 3.9584650693776355
# Finished optimizing.
#
# epoch number =  237
# Current loss: 3.6731133081640155
# Finished optimizing.
#
# epoch number =  238
# Current loss: 3.953674249917433
# Finished optimizing.
#
# epoch number =  239
# Current loss: 3.6684754577597887
# Finished optimizing.
#
# epoch number =  240
# Current loss: 3.94888343081154
# Finished optimizing.
#
# epoch number =  241
# Current loss: 3.6638376070787793
# Finished optimizing.
#
# epoch number =  242
# Current loss: 3.944092612046508
# Finished optimizing.
#
# epoch number =  243
# Current loss: 3.659199756088198
# Finished optimizing.
#
# epoch number =  244
# Current loss: 3.939301793609908
# Finished optimizing.
#
# epoch number =  245
# Current loss: 3.654561904752939
# Finished optimizing.
#
# epoch number =  246
# Current loss: 3.934510975489294
# Finished optimizing.
#
# epoch number =  247
# Current loss: 3.6499240530353934
# Finished optimizing.
#
# epoch number =  248
# Current loss: 3.9297201576727745
# Finished optimizing.
#
# epoch number =  249
# Current loss: 3.6452862008952738
# Finished optimizing.
